# %%
import numpy as np
import pandas as pd
import os
import warnings
warnings.filterwarnings('ignore')


import seaborn as sns
import matplotlib.pyplot as plt


sns.set(style="ticks")

# Defining custom color palette
flatui = ["#9b59b6", "#3498db", "#95a5a6", "#e74c3c", "#34495e", "#2ecc71"]

# Converting hex colors into seaborn color palette
flatui = sns.color_palette(flatui)

# %%
Fifa = pd.read_csv("kl.csv", encoding="latin1")
Fifa
# Out:
#        Unnamed: 0      ID                Name   Age  \
# 0               0  158023            L. Messi  31.0
# 1               1   20801   Cristiano Ronaldo  33.0
# 2               2  190871           Neymar Jr  26.0
# 3               3  193080              De Gea  27.0
# 4               4  192985        K. De Bruyne  27.0
# ...           ...     ...                 ...   ...
# 18202       18202  238813        J. Lundstram  19.0
# 18203       18203  243165  N. Christoffersson  19.0
# 18204       18204  241638           B. Worman  16.0
# 18205       18205  246268      D. Walker-Rice  17.0
# 18206       18206  246269           G. Nugent  16.0
#
#                                                 Photo Nationality  \
# 0      https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1       https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2      https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3      https://cdn.sofifa.org/players/4/19/193080.png       Spain
# ...

# %%
Fifa.head()
# Out:
#    Unnamed: 0      ID               Name   Age  \
# 0           0  158023           L. Messi  31.0
# 1           1   20801  Cristiano Ronaldo  33.0
# 2           2  190871          Neymar Jr  26.0
# 3           3  193080             De Gea  27.0
# 4           4  192985       K. De Bruyne  27.0
#
#                                             Photo Nationality  \
# 0  https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1   https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2  https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3  https://cdn.sofifa.org/players/4/19/193080.png       Spain
# 4  https://cdn.sofifa.org/players/4/19/192985.png     Belgium
#
#                                   Flag  Overall  Potential  \
# 0  https://cdn.sofifa.org/flags/52.png     94.0         94
# 1  https://cdn.sofifa.org/flags/38.png     94.0         94
# 2  https://cdn.sofifa.org/flags/54.png     92.0         93
# 3  https://cdn.sofifa.org/flags/45.png     91.0         93
# ...

# %%
Fifa.tail ()
# Out:
#        Unnamed: 0      ID                Name   Age  \
# 18202       18202  238813        J. Lundstram  19.0
# 18203       18203  243165  N. Christoffersson  19.0
# 18204       18204  241638           B. Worman  16.0
# 18205       18205  246268      D. Walker-Rice  17.0
# 18206       18206  246269           G. Nugent  16.0
#
#                                                 Photo Nationality  \
# 18202  https://cdn.sofifa.org/players/4/19/238813.png     England
# 18203  https://cdn.sofifa.org/players/4/19/243165.png      Sweden
# 18204  https://cdn.sofifa.org/players/4/19/241638.png     England
# 18205  https://cdn.sofifa.org/players/4/19/246268.png     England
# 18206  https://cdn.sofifa.org/players/4/19/246269.png     England
#
#                                       Flag  Overall  Potential  \
# 18202  https://cdn.sofifa.org/flags/14.png     47.0         65
# 18203  https://cdn.sofifa.org/flags/46.png     47.0         63
# ...

# %%
Fifa.shape
# Out:
# (18207, 89)

# %%
Fifa.size
# Out:
# 1620423

# %%
Fifa.columns
# Out:
# Index(['Unnamed: 0', 'ID', 'Name', 'Age', 'Photo', 'Nationality', 'Flag',
#        'Overall', 'Potential', 'Club', 'Club Logo', 'Value', 'Wage', 'Special',
#        'Preferred Foot', 'International Reputation', 'Weak Foot',
#        'Skill Moves', 'Work Rate', 'Body Type', 'Real Face', 'Position',
#        'Jersey Number', 'Joined', 'Loaned From', 'Contract Valid Until',
#        'Height', 'Weight', 'LS', 'ST', 'RS', 'LW', 'LF', 'CF', 'RF', 'RW',
#        'LAM', 'CAM', 'RAM', 'LM', 'LCM', 'CM', 'RCM', 'RM', 'LWB', 'LDM',
#        'CDM', 'RDM', 'RWB', 'LB', 'LCB', 'CB', 'RCB', 'RB', 'Crossing',
#        'Finishing', 'HeadingAccuracy', 'ShortPassing', 'Volleys', 'Dribbling',
#        'Curve', 'FKAccuracy', 'LongPassing', 'BallControl', 'Acceleration',
#        'SprintSpeed', 'Agility', 'Reactions', 'Balance', 'ShotPower',
#        'Jumping', 'Stamina', 'Strength', 'LongShots', 'Aggression',
#        'Interceptions', 'Positioning', 'Vision', 'Penalties', 'Composure',
# ...

# %%
Fifa.dtypes
# Out:
# Unnamed: 0          int64
# ID                  int64
# Name               object
# Age               float64
# Photo              object
#                    ...
# GKHandling        float64
# GKKicking         float64
# GKPositioning     float64
# GKReflexes        float64
# Release Clause     object
# Length: 89, dtype: object

# %%
Fifa['Club'].dtype
# Out:
# dtype('O')

# %%
import missingno as msno

# %%
dump_df = Fifa.iloc[:,15:35]
dump_df.shape
# Out:
# (18207, 20)

# %%
msno.bar (dump_df)
# Out:
# <Axes: >

# %%
Fifa[['Loaned From']]
# Out:
#       Loaned From
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
# ...           ...
# 18202         NaN
# 18203         NaN
# 18204         NaN
# 18205         NaN
# 18206         NaN
#
# [18207 rows x 1 columns]

# %%
dump_df1 = Fifa.loc[:,'Name':'Club']
dump_df1
# Out:
#                      Name   Age  \
# 0                L. Messi  31.0
# 1       Cristiano Ronaldo  33.0
# 2               Neymar Jr  26.0
# 3                  De Gea  27.0
# 4            K. De Bruyne  27.0
# ...                   ...   ...
# 18202        J. Lundstram  19.0
# 18203  N. Christoffersson  19.0
# 18204           B. Worman  16.0
# 18205      D. Walker-Rice  17.0
# 18206           G. Nugent  16.0
#
#                                                 Photo Nationality  \
# 0      https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1       https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2      https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3      https://cdn.sofifa.org/players/4/19/193080.png       Spain
# 4      https://cdn.sofifa.org/players/4/19/192985.png     Belgium
# ...                                               ...         ...
# 18202  https://cdn.sofifa.org/players/4/19/238813.png     England
# ...

# %%
msno.matrix(dump_df)
# Out:
# <Axes: >

# %% [markdown]
# ### Heatmap

# %%
msno.heatmap(dump_df)
# Out:
# <Axes: >

# %%
Fifa.columns
# Out:
# Index(['Unnamed: 0', 'ID', 'Name', 'Age', 'Photo', 'Nationality', 'Flag',
#        'Overall', 'Potential', 'Club', 'Club Logo', 'Value', 'Wage', 'Special',
#        'Preferred Foot', 'International Reputation', 'Weak Foot',
#        'Skill Moves', 'Work Rate', 'Body Type', 'Real Face', 'Position',
#        'Jersey Number', 'Joined', 'Loaned From', 'Contract Valid Until',
#        'Height', 'Weight', 'LS', 'ST', 'RS', 'LW', 'LF', 'CF', 'RF', 'RW',
#        'LAM', 'CAM', 'RAM', 'LM', 'LCM', 'CM', 'RCM', 'RM', 'LWB', 'LDM',
#        'CDM', 'RDM', 'RWB', 'LB', 'LCB', 'CB', 'RCB', 'RB', 'Crossing',
#        'Finishing', 'HeadingAccuracy', 'ShortPassing', 'Volleys', 'Dribbling',
#        'Curve', 'FKAccuracy', 'LongPassing', 'BallControl', 'Acceleration',
#        'SprintSpeed', 'Agility', 'Reactions', 'Balance', 'ShotPower',
#        'Jumping', 'Stamina', 'Strength', 'LongShots', 'Aggression',
#        'Interceptions', 'Positioning', 'Vision', 'Penalties', 'Composure',
# ...

# %%
from wordcloud import WordCloud

# %%
#Plotting the wordcloud for the Nationality column
plt.subplots(figsize=(25,20))
wordcloud = WordCloud(
    background_color='white',
    width=1920,
    height=1080
).generate(" ".join(Fifa.Nationality))
plt.imshow(wordcloud)
plt.axis("off")
plt.savefig("graph.png")
plt.show()

# %% [markdown]
# #### Impuiting  the missing values for the columns 'Club' and 'Position'

# %%
Fifa[['Club']]
# Out:
#                       Club
# 0             FC Barcelona
# 1                 Juventus
# 2      Paris Saint-Germain
# 3        Manchester United
# 4          Manchester City
# ...                    ...
# 18202      Crewe Alexandra
# 18203       Trelleborgs FF
# 18204     Cambridge United
# 18205      Tranmere Rovers
# 18206      Tranmere Rovers
#
# [18207 rows x 1 columns]

# %%
Fifa[['Position']]
# Out:
#       Position
# 0           RF
# 1           ST
# 2           LW
# 3           GK
# 4          RCM
# ...        ...
# 18202       CM
# 18203       ST
# 18204       ST
# 18205       RW
# 18206       CM
#
# [18207 rows x 1 columns]

# %%
Fifa.columns
# Out:
# Index(['Unnamed: 0', 'ID', 'Name', 'Age', 'Photo', 'Nationality', 'Flag',
#        'Overall', 'Potential', 'Club', 'Club Logo', 'Value', 'Wage', 'Special',
#        'Preferred Foot', 'International Reputation', 'Weak Foot',
#        'Skill Moves', 'Work Rate', 'Body Type', 'Real Face', 'Position',
#        'Jersey Number', 'Joined', 'Loaned From', 'Contract Valid Until',
#        'Height', 'Weight', 'LS', 'ST', 'RS', 'LW', 'LF', 'CF', 'RF', 'RW',
#        'LAM', 'CAM', 'RAM', 'LM', 'LCM', 'CM', 'RCM', 'RM', 'LWB', 'LDM',
#        'CDM', 'RDM', 'RWB', 'LB', 'LCB', 'CB', 'RCB', 'RB', 'Crossing',
#        'Finishing', 'HeadingAccuracy', 'ShortPassing', 'Volleys', 'Dribbling',
#        'Curve', 'FKAccuracy', 'LongPassing', 'BallControl', 'Acceleration',
#        'SprintSpeed', 'Agility', 'Reactions', 'Balance', 'ShotPower',
#        'Jumping', 'Stamina', 'Strength', 'LongShots', 'Aggression',
#        'Interceptions', 'Positioning', 'Vision', 'Penalties', 'Composure',
# ...

# %%
dump_df2 = Fifa.iloc[:7,:23]
dump_df2
# Out:
#    Unnamed: 0      ID               Name   Age  \
# 0           0  158023           L. Messi  31.0
# 1           1   20801  Cristiano Ronaldo  33.0
# 2           2  190871          Neymar Jr  26.0
# 3           3  193080             De Gea  27.0
# 4           4  192985       K. De Bruyne  27.0
# 5           5  183277          E. Hazard  27.0
# 6           6  177003          L. Modri?  32.0
#
#                                             Photo Nationality  \
# 0  https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1   https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2  https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3  https://cdn.sofifa.org/players/4/19/193080.png       Spain
# 4  https://cdn.sofifa.org/players/4/19/192985.png     Belgium
# 5  https://cdn.sofifa.org/players/4/19/183277.png     Belgium
# 6  https://cdn.sofifa.org/players/4/19/177003.png     Croatia
#
#                                   Flag  Overall  Potential  \
# ...

# %%
msno.bar(dump_df2)
# Out:
# <Axes: >

# %%
Fifa['Club'].fillna('No Club',inplace = True)
Fifa['Position'].fillna('ST',inplace = True)

# %% [markdown]
# #### Selecting Numeric Skill Columns to Impute Missing Values Using Mean

# %%
Fifa.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18207 entries, 0 to 18206
# Data columns (total 89 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Unnamed: 0                18207 non-null  int64
#  1   ID                        18207 non-null  int64
#  2   Name                      18207 non-null  object
#  3   Age                       18206 non-null  float64
#  4   Photo                     18207 non-null  object
#  5   Nationality               18207 non-null  object
#  6   Flag                      18207 non-null  object
#  7   Overall                   18206 non-null  float64
#  8   Potential                 18207 non-null  int64
#  9   Club                      18207 non-null  object
#  10  Club Logo                 18207 non-null  object
#  11  Value                     18207 non-null  object
#  12  Wage                      18207 non-null  object
# ...

# %%
# Selecting numeric skill columns to impute missing values using mean

skill_cols = [
    'Crossing', 'Finishing', 'HeadingAccuracy', 'ShortPassing', 'Volleys',
    'Dribbling', 'Curve', 'FKAccuracy', 'LongPassing', 'BallControl',
    'Acceleration', 'SprintSpeed', 'Agility', 'Reactions', 'Balance',
    'ShotPower', 'Jumping', 'Stamina', 'Strength', 'LongShots',
    'Aggression', 'Interceptions', 'Positioning', 'Vision', 'Penalties',
    'Composure', 'Marking', 'StandingTackle', 'SlidingTackle',
    'GKDiving', 'GKHandling', 'GKKicking', 'GKPositioning', 'GKReflexes'
]

to_impute_by_mean = Fifa.loc[:, skill_cols]

# %%
to_impute_by_mean
# Out:
#        Crossing  Finishing  HeadingAccuracy  ShortPassing  Volleys  Dribbling  \
# 0          84.0       95.0             70.0          90.0     86.0       97.0
# 1          84.0       94.0             89.0          81.0     87.0       88.0
# 2          79.0       87.0             62.0          84.0     84.0       96.0
# 3          17.0       13.0             21.0          50.0     13.0       18.0
# 4          93.0       82.0             55.0          92.0     82.0       86.0
# ...         ...        ...              ...           ...      ...        ...
# 18202      34.0       38.0             40.0          49.0     25.0       42.0
# 18203      23.0       52.0             52.0          43.0     36.0       39.0
# 18204      25.0       40.0             46.0          38.0     38.0       45.0
# 18205      44.0       50.0             39.0          42.0     40.0       51.0
# 18206      41.0       34.0             46.0          48.0     30.0       43.0
#
# ...

# %%
#Replacing the missing values with mean

Fifa[to_impute_by_mean.columns] = Fifa[to_impute_by_mean.columns].fillna(
    Fifa[to_impute_by_mean.columns].mean()
)

# %%
#This is our categorical variables and will be imputed by mode.

to_impute_by_mode = Fifa.loc[:,['Body Type','International Reputation','Height','Weight','Preferred Foot','Jersey Number',]]
for i in to_impute_by_mode.columns:
    Fifa[i].fillna(Fifa[i].mode()[0],inplace = True)

# %%
Fifa['Overall'].isnull().sum
# Out:
# <bound method Series.sum of 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 18202    False
# 18203    False
# 18204    False
# 18205    False
# 18206    False
# Name: Overall, Length: 18207, dtype: bool>

# %%
Fifa.head(20)
# Out:
#     Unnamed: 0      ID               Name   Age  \
# 0            0  158023           L. Messi  31.0
# 1            1   20801  Cristiano Ronaldo  33.0
# 2            2  190871          Neymar Jr  26.0
# 3            3  193080             De Gea  27.0
# 4            4  192985       K. De Bruyne  27.0
# 5            5  183277          E. Hazard  27.0
# 6            6  177003          L. Modri?  32.0
# 7            7  176580          L. Suárez  31.0
# 8            8  155862       Sergio Ramos  32.0
# 9            9  200389           J. Oblak  25.0
# 10          10  188545     R. Lewandowski  29.0
# 11          11  182521           T. Kroos   NaN
# 12          12  182493           D. Godín  32.0
# 13          13  168542        David Silva  32.0
# 14          14  215914           N. Kanté  27.0
# 15          15  211110          P. Dybala  24.0
# 16          16  202126            H. Kane  24.0
# 17          17  194765       A. Griezmann  27.0
# ...

# %%
#Columns remaining to be imputed
Fifa.columns[Fifa.isna().any()]
# Out:
# Index(['Age', 'Overall', 'Weak Foot', 'Skill Moves', 'Work Rate', 'Real Face',
#        'Joined', 'Loaned From', 'Contract Valid Until', 'LS', 'ST', 'RS', 'LW',
#        'LF', 'CF', 'RF', 'RW', 'LAM', 'CAM', 'RAM', 'LM', 'LCM', 'CM', 'RCM',
#        'RM', 'LWB', 'LDM', 'CDM', 'RDM', 'RWB', 'LB', 'LCB', 'CB', 'RCB', 'RB',
#        'Release Clause'],
#       dtype='object')

# %%
#Fillinng the remaining missing values with 0.

Fifa.fillna(0,inplace = True)
Fifa.head(25)
# Out:
#     Unnamed: 0      ID               Name   Age  \
# 0            0  158023           L. Messi  31.0
# 1            1   20801  Cristiano Ronaldo  33.0
# 2            2  190871          Neymar Jr  26.0
# 3            3  193080             De Gea  27.0
# 4            4  192985       K. De Bruyne  27.0
# 5            5  183277          E. Hazard  27.0
# 6            6  177003          L. Modri?  32.0
# 7            7  176580          L. Suárez  31.0
# 8            8  155862       Sergio Ramos  32.0
# 9            9  200389           J. Oblak  25.0
# 10          10  188545     R. Lewandowski  29.0
# 11          11  182521           T. Kroos   0.0
# 12          12  182493           D. Godín  32.0
# 13          13  168542        David Silva  32.0
# 14          14  215914           N. Kanté  27.0
# 15          15  211110          P. Dybala  24.0
# 16          16  202126            H. Kane  24.0
# 17          17  194765       A. Griezmann  27.0
# ...

# %%
#Functions to get the rounded values from different columns.

def defending(data):
    return int(round(data[['Marking','StandingTackle','SlidingTackle']].mean().mean()))

def general(data):
    return int(round(data[['HeadingAccuracy','Dribbling','Curve','BallControl']].mean().mean()))

def mental(data):
    return int(round(data[['Aggression', 'Interceptions', 'Positioning', 'Vision', 'Composure']].mean().mean()))

def passing(data):
    return int(round(data[['Crossing', 'ShortPassing', 'LongPassing']].mean().mean()))

def mobility(data):
    return int(round(data[['Acceleration', 'SprintSpeed', 'Agility', 'Reactions']].mean().mean()))

def power(data):
    return int(round(data[['Balance', 'Jumping', 'Stamina', 'Strength']].mean().mean()))

def rating(data):
    return int(round(data[['Potential', 'Overall']].mean().mean()))

def shooting(data):
    return int(round(data[['Finishing', 'Volleys', 'FKAccuracy', 'ShotPower', 'LongShots', 'Penalties']].mean().mean()))

# %%
Fifa[['Club Logo']].isnull().sum
# Out:
# <bound method DataFrame.sum of        Club Logo
# 0          False
# 1          False
# 2          False
# 3          False
# 4          False
# ...          ...
# 18202      False
# 18203      False
# 18204      False
# 18205      False
# 18206      False
#
# [18207 rows x 1 columns]>

# %%
Fifa.columns
# Out:
# Index(['Unnamed: 0', 'ID', 'Name', 'Age', 'Photo', 'Nationality', 'Flag',
#        'Overall', 'Potential', 'Club', 'Club Logo', 'Value', 'Wage', 'Special',
#        'Preferred Foot', 'International Reputation', 'Weak Foot',
#        'Skill Moves', 'Work Rate', 'Body Type', 'Real Face', 'Position',
#        'Jersey Number', 'Joined', 'Loaned From', 'Contract Valid Until',
#        'Height', 'Weight', 'LS', 'ST', 'RS', 'LW', 'LF', 'CF', 'RF', 'RW',
#        'LAM', 'CAM', 'RAM', 'LM', 'LCM', 'CM', 'RCM', 'RM', 'LWB', 'LDM',
#        'CDM', 'RDM', 'RWB', 'LB', 'LCB', 'CB', 'RCB', 'RB', 'Crossing',
#        'Finishing', 'HeadingAccuracy', 'ShortPassing', 'Volleys', 'Dribbling',
#        'Curve', 'FKAccuracy', 'LongPassing', 'BallControl', 'Acceleration',
#        'SprintSpeed', 'Agility', 'Reactions', 'Balance', 'ShotPower',
#        'Jumping', 'Stamina', 'Strength', 'LongShots', 'Aggression',
#        'Interceptions', 'Positioning', 'Vision', 'Penalties', 'Composure',
# ...

# %%
#Renamining a column

Fifa.rename(columns = {'Club Logo':'Club_Logo'},inplace = True)

# %%
Fifa['defending'] = Fifa.apply(defending, axis = 1)
Fifa['general'] = Fifa.apply(general, axis = 1)
Fifa['mental'] = Fifa.apply(mental, axis = 1)
Fifa['passing'] = Fifa.apply(passing, axis = 1)
Fifa['mobility'] = Fifa.apply(mobility, axis = 1)
Fifa['power'] = Fifa.apply(power, axis = 1)
Fifa['rating'] = Fifa.apply(rating, axis = 1)
Fifa['shooting'] = Fifa.apply(shooting, axis = 1)

# %%
Fifa.rename(columns={
    'defending': 'Defending',
    'general': 'General',
    'mental' : 'Mental',
    'passing' : 'Passing',
    'mobility' : 'Mobililty',
    'power' : 'Power',
    'rating' : 'Rating',
    'shooting'  : 'Shooting'
    
}, inplace=True)

# %%
Fifa.head()
# Out:
#    Unnamed: 0      ID               Name   Age  \
# 0           0  158023           L. Messi  31.0
# 1           1   20801  Cristiano Ronaldo  33.0
# 2           2  190871          Neymar Jr  26.0
# 3           3  193080             De Gea  27.0
# 4           4  192985       K. De Bruyne  27.0
#
#                                             Photo Nationality  \
# 0  https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1   https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2  https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3  https://cdn.sofifa.org/players/4/19/193080.png       Spain
# 4  https://cdn.sofifa.org/players/4/19/192985.png     Belgium
#
#                                   Flag  Overall  Potential  \
# 0  https://cdn.sofifa.org/flags/52.png     94.0         94
# 1  https://cdn.sofifa.org/flags/38.png     94.0         94
# 2  https://cdn.sofifa.org/flags/54.png     92.0         93
# 3  https://cdn.sofifa.org/flags/45.png     91.0         93
# ...

# %%
#Creating the players dataset
Players = Fifa[['Name','Defending','General','Mental','Passing','Mobililty','Power','Rating','Shooting']]

# %%
Players.head()
# Out:
#                 Name  Defending  General  Mental  Passing  Mobililty  Power  \
# 0           L. Messi         29       89      71       87         91     74
# 1  Cristiano Ronaldo         27       88      73       81         91     83
# 2          Neymar Jr         28       85      72       80         94     69
# 3             De Gea         16       26      43       39         66     54
# 4       K. De Bruyne         59       79      81       92         81     76
#
#    Rating  Shooting
# 0      94        88
# 1      94        88
# 2      92        84
# 3      92        21
# 4      92        85

# %%
#Different Position acquired by the players
plt.figure(figsize = (18, 8))
plt.style.use('fivethirtyeight')
ax = sns.countplot(x = 'Position', data = Fifa, palette = 'dark')
ax.set_xlabel(xlabel = 'Different Positions in Football', fontsize = 16)
ax.set_ylabel(ylabel = 'Count of Players', fontsize = 16)
ax.set_title(label = 'Comparison of Positions and Players', fontsize = 20)
plt.show()

# %%
some_countries = ("England", "Germany", "Spain", 
                  "Argentina", "France", 
                  "Brazil", "Italy", "Colombia")

data_countries = Fifa.loc[
    Fifa["Nationality"].isin(some_countries)
]

data_countries.head()
# Out:
#     Unnamed: 0      ID          Name   Age  \
# 0            0  158023      L. Messi  31.0
# 2            2  190871     Neymar Jr  26.0
# 3            3  193080        De Gea  27.0
# 8            8  155862  Sergio Ramos  32.0
# 11          11  182521      T. Kroos   0.0
#
#                                              Photo Nationality  \
# 0   https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 2   https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3   https://cdn.sofifa.org/players/4/19/193080.png       Spain
# 8   https://cdn.sofifa.org/players/4/19/155862.png       Spain
# 11  https://cdn.sofifa.org/players/4/19/182521.png     Germany
#
#                                    Flag  Overall  Potential  \
# 0   https://cdn.sofifa.org/flags/52.png     94.0         94
# 2   https://cdn.sofifa.org/flags/54.png     92.0         93
# 3   https://cdn.sofifa.org/flags/45.png     91.0         93
# 8   https://cdn.sofifa.org/flags/45.png     91.0         91
# ...

# %%
sns.barplot(
    x='Nationality',
    y='Overall',
    data=data_countries,
    order=data_countries.groupby('Nationality')['Overall']
          .mean()
          .sort_values(ascending=False)
          .index,
    palette='viridis'
)
# Out:
# <Axes: xlabel='Nationality', ylabel='Overall'>

# %%
Data = Fifa.copy()

# %%
Data
# Out:
#        Unnamed: 0      ID                Name   Age  \
# 0               0  158023            L. Messi  31.0
# 1               1   20801   Cristiano Ronaldo  33.0
# 2               2  190871           Neymar Jr  26.0
# 3               3  193080              De Gea  27.0
# 4               4  192985        K. De Bruyne  27.0
# ...           ...     ...                 ...   ...
# 18202       18202  238813        J. Lundstram  19.0
# 18203       18203  243165  N. Christoffersson  19.0
# 18204       18204  241638           B. Worman  16.0
# 18205       18205  246268      D. Walker-Rice  17.0
# 18206       18206  246269           G. Nugent  16.0
#
#                                                 Photo Nationality  \
# 0      https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1       https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2      https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3      https://cdn.sofifa.org/players/4/19/193080.png       Spain
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.style.use("fivethirtyeight")
sns.set(style="ticks")

# Selected clubs
some_clubs = (
    "CD Leganés", "Southampton", "RC Celta", "Napoli",
    "Fortuna Düsseldorf", "Manchester City",
    "Tottenham Hotspur", "FC Barcelona",
    "Valencia CF", "Chelsea", "Real Madrid"
)

# Filtering players from selected clubs
Data_clubs = Data.loc[
    Data['Club'].isin(some_clubs)
]

# Display first 5 rows
Data_clubs.head()
# Out:
#    Unnamed: 0      ID          Name   Age  \
# 0           0  158023      L. Messi  31.0
# 4           4  192985  K. De Bruyne  27.0
# 5           5  183277     E. Hazard  27.0
# 6           6  177003     L. Modri?  32.0
# 7           7  176580     L. Suárez  31.0
#
#                                             Photo Nationality  \
# 0  https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 4  https://cdn.sofifa.org/players/4/19/192985.png     Belgium
# 5  https://cdn.sofifa.org/players/4/19/183277.png     Belgium
# 6  https://cdn.sofifa.org/players/4/19/177003.png     Croatia
# 7  https://cdn.sofifa.org/players/4/19/176580.png     Uruguay
#
#                                   Flag  Overall  Potential             Club  \
# 0  https://cdn.sofifa.org/flags/52.png     94.0         94     FC Barcelona
# 4   https://cdn.sofifa.org/flags/7.png     91.0         92  Manchester City
# 5   https://cdn.sofifa.org/flags/7.png     91.0         91          Chelsea
# ...

# %%
sns.boxplot(x = 'Club',
            y = 'Overall',
            data = Data_clubs,
                order=Data_clubs.groupby('Club')['Overall']
          .median()
          .sort_values(ascending=False)
          .index,
    palette='inferno'
)
plt.xticks(rotation=90)
plt.show()

# %%
Data.columns
# Out:
# Index(['Unnamed: 0', 'ID', 'Name', 'Age', 'Photo', 'Nationality', 'Flag',
#        'Overall', 'Potential', 'Club', 'Club_Logo', 'Value', 'Wage', 'Special',
#        'Preferred Foot', 'International Reputation', 'Weak Foot',
#        'Skill Moves', 'Work Rate', 'Body Type', 'Real Face', 'Position',
#        'Jersey Number', 'Joined', 'Loaned From', 'Contract Valid Until',
#        'Height', 'Weight', 'LS', 'ST', 'RS', 'LW', 'LF', 'CF', 'RF', 'RW',
#        'LAM', 'CAM', 'RAM', 'LM', 'LCM', 'CM', 'RCM', 'RM', 'LWB', 'LDM',
#        'CDM', 'RDM', 'RWB', 'LB', 'LCB', 'CB', 'RCB', 'RB', 'Crossing',
#        'Finishing', 'HeadingAccuracy', 'ShortPassing', 'Volleys', 'Dribbling',
#        'Curve', 'FKAccuracy', 'LongPassing', 'BallControl', 'Acceleration',
#        'SprintSpeed', 'Agility', 'Reactions', 'Balance', 'ShotPower',
#        'Jumping', 'Stamina', 'Strength', 'LongShots', 'Aggression',
#        'Interceptions', 'Positioning', 'Vision', 'Penalties', 'Composure',
# ...

# %%
Data[['Preferred Foot']]
# Out:
#       Preferred Foot
# 0               Left
# 1              Right
# 2              Right
# 3              Right
# 4              Right
# ...              ...
# 18202          Right
# 18203          Right
# 18204          Right
# 18205          Right
# 18206          Right
#
# [18207 rows x 1 columns]

# %%
#Finding the top 10 left-footed player
left_data = Data[Data['Preferred Foot'] == 'Left'][
    ['Name', 'Age', 'Club', 'Nationality']
].head(10)

left_data
# Out:
#             Name   Age               Club Nationality
# 0       L. Messi  31.0       FC Barcelona   Argentina
# 13   David Silva  32.0    Manchester City       Spain
# 15     P. Dybala  24.0           Juventus   Argentina
# 17  A. Griezmann  27.0    Atlético Madrid      France
# 19   T. Courtois  26.0        Real Madrid     Belgium
# 24  G. Chiellini  33.0           Juventus       Italy
# 26      M. Salah  26.0          Liverpool       Egypt
# 28  J. Rodríguez  26.0  FC Bayern München    Colombia
# 35       Marcelo  30.0        Real Madrid      Brazil
# 36       G. Bale  28.0        Real Madrid       Wales

# %%
#Finding the top 10 left-footed player
right_data = Data[Data['Preferred Foot'] == 'Right'][
    ['Name', 'Age', 'Club', 'Nationality']
].head(10)

right_data
# Out:
#                  Name   Age                 Club Nationality
# 1   Cristiano Ronaldo  33.0             Juventus    Portugal
# 2           Neymar Jr  26.0  Paris Saint-Germain      Brazil
# 3              De Gea  27.0    Manchester United       Spain
# 4        K. De Bruyne  27.0      Manchester City     Belgium
# 5           E. Hazard  27.0              Chelsea     Belgium
# 6           L. Modri?  32.0          Real Madrid     Croatia
# 7           L. Suárez  31.0         FC Barcelona     Uruguay
# 8        Sergio Ramos  32.0          Real Madrid       Spain
# 9            J. Oblak  25.0      Atlético Madrid    Slovenia
# 10     R. Lewandowski  29.0    FC Bayern München      Poland

# %%
right_data.shape
# Out:
# (10, 4)

# %%
sns.lmplot(
    x='BallControl',
    y='Dribbling',
    data=Data,
    col='Preferred Foot'
)

plt.show()

# %%
Data.groupby('Club')['Nationality'].nunique().sort_values(ascending=False).head(10)
# Out:
# Club
# No Club                   28
# Brighton & Hove Albion    21
# Fulham                    19
# Udinese                   18
# Lazio                     18
# AS Monaco                 18
# West Ham United           18
# Empoli                    18
# Eintracht Frankfurt       18
# Napoli                    18
# Name: Nationality, dtype: int64

# %%
Fifa.Nationality.unique
# Out:
# <bound method Series.unique of 0        Argentina
# 1         Portugal
# 2           Brazil
# 3            Spain
# 4          Belgium
#            ...
# 18202      England
# 18203       Sweden
# 18204      England
# 18205      England
# 18206      England
# Name: Nationality, Length: 18207, dtype: object>

# %%
Fifa.Club.unique()
# Out:
# array(['FC Barcelona', 'Juventus', 'Paris Saint-Germain',
#        'Manchester United', 'Manchester City', 'Chelsea', 'Real Madrid',
#        'Atlético Madrid', 'FC Bayern München', 'Tottenham Hotspur',
#        'Liverpool', 'Napoli', 'Arsenal', 'Milan', 'Inter', 'Lazio',
#        'Borussia Dortmund', 'Vissel Kobe', 'Olympique Lyonnais', 'Roma',
#        'Valencia CF', 'Guangzhou Evergrande Taobao FC', 'FC Porto',
#        'FC Schalke 04', 'Be?ikta? JK', 'LA Galaxy', 'Sporting CP',
#        'Real Betis', 'Olympique de Marseille', 'RC Celta',
#        'Bayer 04 Leverkusen', 'Real Sociedad', 'Villarreal CF',
#        'Sevilla FC', 'SL Benfica', 'AS Saint-Étienne', 'AS Monaco',
#        'Leicester City', 'Atalanta', 'Grêmio', 'Atlético Mineiro',
#        'RB Leipzig', 'Ajax', 'Dalian YiFang FC', 'Everton',
#        'West Ham United', '1. FC Köln', 'TSG 1899 Hoffenheim',
#        'Shanghai SIPG FC', 'OGC Nice', 'Al Nassr',
#        'Wolverhampton Wanderers', 'Borussia Mönchengladbach',
# ...

# %%
Fifa[['Potential']]
# Out:
#        Potential
# 0             94
# 1             94
# 2             93
# 3             93
# 4             92
# ...          ...
# 18202         65
# 18203         63
# 18204         67
# 18205         66
# 18206         66
#
# [18207 rows x 1 columns]

# %%
#Player with maximum potential and overall performance
player = str(Fifa.loc[Fifa['Potential'].idxmax()][1])

print("Maximum Potential: " + str(Fifa.loc[Fifa['Potential'].idxmax()][1]))
print("Maximum Overall Performance: " + str(Fifa.loc[Fifa["Overall"].idxmax()][1]))
# Out:
# Maximum Potential: 231747
# Maximum Overall Performance: 158023

# %%
#Finding the best players for each performance criteria
H_Prfrmnc= ['Crossing', 'Finishing', 'HeadingAccuracy', 'ShortPassing', 
           'Volleys', 'Dribbling', 'Curve', 'FKAccuracy', 'LongPassing', 
           'BallControl', 'Acceleration', 'SprintSpeed', 'Agility', 
           'Reactions', 'Balance', 'ShotPower', 'Jumping', 'Stamina', 
           'Strength', 'LongShots', 'Aggression', 'Interceptions', 
           'Positioning', 'Vision', 'Penalties', 'Composure', 
           'Marking', 'StandingTackle', 'SlidingTackle', 
           'GKDiving', 'GKHandling', 'GKKicking', 
           'GKPositioning', 'GKReflexes']

for col in H_Prfrmnc:
    best_player = Fifa.loc[Fifa[col].idxmax()]['Name']
    print(f"Best {col}: {best_player}")
# Out:
# Best Crossing: K. De Bruyne
# Best Finishing: L. Messi
# Best HeadingAccuracy: Naldo
# Best ShortPassing: L. Modri?
# Best Volleys: E. Cavani
# Best Dribbling: L. Messi
# Best Curve: Quaresma
# Best FKAccuracy: L. Messi
# Best LongPassing: T. Kroos
# Best BallControl: L. Messi
# Best Acceleration: Douglas Costa
# Best SprintSpeed: K. Mbappé
# Best Agility: Neymar Jr
# Best Reactions: Cristiano Ronaldo
# Best Balance: Bernard
# Best ShotPower: Cristiano Ronaldo
# Best Jumping: Cristiano Ronaldo
# Best Stamina: N. Kanté
# Best Strength: A. Akinfenwa
# Best LongShots: L. Messi
# Best Aggression: B. Pearson
# Best Interceptions: N. Kanté
# Best Positioning: Cristiano Ronaldo
# Best Vision: L. Messi
# Best Penalties: M. Balotelli
# Best Composure: L. Messi
# Best Marking: A. Barzagli
# Best StandingTackle: G. Chiellini
# Best SlidingTackle: Sergio Ramos
# Best GKDiving: De Gea
# Best GKHandling: J. Oblak
# Best GKKicking: M. Neuer
# Best GKPositioning: G. Buffon
# Best GKReflexes: De Gea

# %%
Fifa.columns
# Out:
# Index(['Unnamed: 0', 'ID', 'Name', 'Age', 'Photo', 'Nationality', 'Flag',
#        'Overall', 'Potential', 'Club', 'Club_Logo', 'Value', 'Wage', 'Special',
#        'Preferred Foot', 'International Reputation', 'Weak Foot',
#        'Skill Moves', 'Work Rate', 'Body Type', 'Real Face', 'Position',
#        'Jersey Number', 'Joined', 'Loaned From', 'Contract Valid Until',
#        'Height', 'Weight', 'LS', 'ST', 'RS', 'LW', 'LF', 'CF', 'RF', 'RW',
#        'LAM', 'CAM', 'RAM', 'LM', 'LCM', 'CM', 'RCM', 'RM', 'LWB', 'LDM',
#        'CDM', 'RDM', 'RWB', 'LB', 'LCB', 'CB', 'RCB', 'RB', 'Crossing',
#        'Finishing', 'HeadingAccuracy', 'ShortPassing', 'Volleys', 'Dribbling',
#        'Curve', 'FKAccuracy', 'LongPassing', 'BallControl', 'Acceleration',
#        'SprintSpeed', 'Agility', 'Reactions', 'Balance', 'ShotPower',
#        'Jumping', 'Stamina', 'Strength', 'LongShots', 'Aggression',
#        'Interceptions', 'Positioning', 'Vision', 'Penalties', 'Composure',
# ...

# %%
Fifa[['Real Face']]
# Out:
#       Real Face
# 0           Yes
# 1           Yes
# 2           Yes
# 3           Yes
# 4           Yes
# ...         ...
# 18202        No
# 18203        No
# 18204        No
# 18205        No
# 18206        No
#
# [18207 rows x 1 columns]

# %%
# Plot to show the preferred foot choice of different players
f, ax = plt.subplots(figsize=(8, 6))
sns.countplot(x="Preferred Foot", hue="Real Face", data=Fifa,palette = "spring")
plt.show()

# %%
#Showing the name of the players which occurs the most number of times from the first 20 names
plt.subplots(figsize=(25,15))

wordcloud = WordCloud(
    background_color="green",
    width=1920,
    height=1000
).generate(" ".join(Fifa.Name[0:20]))

plt.imshow(wordcloud)
plt.axis("off")
plt.savefig("players.png")
plt.show()
